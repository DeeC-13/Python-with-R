# %% [markdown]
# # NPA Data Science: Data Science Outcome 3 Assessment
# ## Student Notebook - Edinburgh College, June 2022

# %% [markdown]
# <div class="alert alert-block alert-warning"><b>Important:</b>
# Add your Name and Student Number to the next cell</div>

# %% [markdown]
# #### Student Name: Darlene Couch
# #### Student Number: EC2307289

# %% [markdown]
# <div class="alert alert-block alert-success"><b>First:</b>
# Read the instructions and look at links to the data provided</div>

# %% [markdown]
# ## Assessment Instructions
# * This assessment covers outcome 3 of the Data Science unit
#
# ## Analyse a dataset to make predictions.
#
# #### Performance criteria
# * a) Define the required analyses and data models.
# * b) Create a relational data model from external sources of data.
# * c) Perform data transformation to complete, correct and structure data.
# * d) Perform descriptive and predictive analyses on the data.
# * e) Create data visualisations and data dashboards to provide insights.
# * f) Identify potential sources of bias in the analysis.
#
# ### Assessment guidance
# * There are 30 marks available and the pass mark is 18/30 or 60%
# * You will be required to provide responses to a series of tasks, and add code to this notebook
# * You are required to pass in order to achieve the assessment for this outcome
# * When completed you should download this notebook file and rename it with your student number, once downloaded please upload to your completed notebook (`.ipynb` file) to the Moodle page before the submission date

# %% [markdown]
# ## Background information - Human Development Index (HDI)
# The HDI was created to emphasise that people and their capabilities should be the ultimate criteria for assessing the development of a country, not economic growth alone. Consider the following:
# * [The Human Development Index](http://hdr.undp.org/en/content/human-development-index-hdi)
# * [Understanding the Data](https://hdr.undp.org/data-center/documentation-and-downloads)
# * [Technical Notes](http://hdr.undp.org/sites/default/files/hdr2016_technical_notes.pdf)
# * [Human Development Data](http://hdr.undp.org/en/data)

# %% [markdown]
# ## Assessment Questions

# %% [markdown]
# <div class="alert alert-block alert-info"><b>Note:</b>
# Add your answer to the cell provided below each question</div>

# %% [markdown]
# ### Task 1: Dataset comprehension (4 marks)
# Based on the links provided in the background information section:
# <br>
# (a) What is the Human Development Index (HDI) and how has it been calculated?
# <br>
# (b) What components make up the HDI?

# %% [markdown]
# ### Task 1: Answer
# * (a) It is a measurement of human development using key areas of human development. It measures the average achievements of a country. It takes the geometric mean of the 3 components by taking the product of those numbers and finds the cube root. It is calculated on a basis of 0 to 1.
# * (b) The components are - a long & healthy life, knowledge and a decent standard of living

# %% [markdown]
# ### Task 2: Examine information and draw conclusions (3 marks)
# Download the ```hdi_by_year.csv``` and the ```hdi_and _components.csv``` from Moodle, based on these files:
# (a) What patterns can be seen from the top 10 countries, is there a trend?
# <br>
# (b) From the data, identify a country that isn't following the overall trend?
# <br>
# (c) Based on your answer for 2(b) identify which dimension of the HDI is having the biggest effect on this country?

# %% [markdown]
# ### Task 2: Answer
# * (a) The number seems to be very very slowly rising each year by extremely small increments. If it does dip a little it then recovers.
# * (b) lebanon
# * (c) GNI per capita

# %% [markdown]
# ### Task 3: Dataset activity (2 marks)
# (a) Import the ```hdi_and _components.csv``` as Pandas a dataframe and print the first 5 rows <br>
# (b) Subset the HDI dataset to it's component indicators and indices, create three new data frames, in each have the HDI rank and country name then add:
# 1) Life expectancy index to ```df_le```
# 2) GNI per capita and GNI per capita rank HDI rank to ```df_gni```
# 3) Expected years of schooling and mean years of schooling to ```df_se```

# %% [markdown]
# ### Task 3: Answer
# add the code to the cells provided for task 3

# %%
# Task 3a answer here:

datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
df.head(5)
# Out:
#    HDI Rank 2020                 Country                    HDI Level  \
# 0            1.0                  Norway  VERY HIGH HUMAN DEVELOPMENT
# 1            2.0                 Ireland  VERY HIGH HUMAN DEVELOPMENT
# 2            2.0             Switzerland  VERY HIGH HUMAN DEVELOPMENT
# 3            4.0  Hong Kong, China (SAR)  VERY HIGH HUMAN DEVELOPMENT
# 4            4.0                 Iceland  VERY HIGH HUMAN DEVELOPMENT
#
#    Human Development Index (HDI) Value 2019  Life expectancy at birth (years)  \
# 0                                     0.957                              82.4
# 1                                     0.955                              82.3
# 2                                     0.955                              83.8
# 3                                     0.949                              84.9
# 4                                     0.949                              83.0
#
#   Unnamed: 5  Expected years of schooling (years) 2019 Unnamed: 7  \
# ...

# %%
# Task 3b.1 answer here:

datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
df.head(5)

df_le = df[['HDI Rank 2020', 'Country', 'Life expectancy at birth (years)']].copy()
print(df_le)
# Out:
#      HDI Rank 2020                 Country  Life expectancy at birth (years)
# 0              1.0                  Norway                              82.4
# 1              2.0                 Ireland                              82.3
# 2              2.0             Switzerland                              83.8
# 3              4.0  Hong Kong, China (SAR)                              84.9
# 4              4.0                 Iceland                              83.0
# ..             ...                     ...                               ...
# 190            NaN                  Monaco                               NaN
# 191            NaN                   Nauru                               NaN
# 192            NaN              San Marino                               NaN
# 193            NaN                 Somalia                              57.4
# 194            NaN                  Tuvalu                               NaN
#
# [195 rows x 3 columns]

# %%
# Task 3b.2 answer here:
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
df.head(5)

df_gni = df[['HDI Rank 2020', 'Country', 'Gross national income (GNI) per capita (2019)', 'GNI per capita rank minus HDI rank 2019']].copy()
print(df_gni)
# Out:
#      HDI Rank 2020                 Country  \
# 0              1.0                  Norway
# 1              2.0                 Ireland
# 2              2.0             Switzerland
# 3              4.0  Hong Kong, China (SAR)
# 4              4.0                 Iceland
# ..             ...                     ...
# 190            NaN                  Monaco
# 191            NaN                   Nauru
# 192            NaN              San Marino
# 193            NaN                 Somalia
# 194            NaN                  Tuvalu
#
#      Gross national income (GNI) per capita (2019)  \
# 0                                          66494.0
# 1                                          68371.0
# 2                                          69394.0
# 3                                          62985.0
# 4                                          54682.0
# ..                                             ...
# 190                                            NaN
# ...

# %%
# Task 3b.3 answer here:
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
df.head(5)

df_se = df[['HDI Rank 2020', 'Country', 'Expected years of schooling (years) 2019', 'Mean years of schooling (years) 2019']].copy()
print(df_se)
# Out:
#      HDI Rank 2020                 Country  \
# 0              1.0                  Norway
# 1              2.0                 Ireland
# 2              2.0             Switzerland
# 3              4.0  Hong Kong, China (SAR)
# 4              4.0                 Iceland
# ..             ...                     ...
# 190            NaN                  Monaco
# 191            NaN                   Nauru
# 192            NaN              San Marino
# 193            NaN                 Somalia
# 194            NaN                  Tuvalu
#
#      Expected years of schooling (years) 2019  \
# 0                                        18.1
# 1                                        18.7
# 2                                        16.3
# 3                                        16.9
# 4                                        19.1
# ..                                        ...
# 190                                       NaN
# 191                                      11.2
# ...

# %% [markdown]
# ### Task 4: Quality and cleaning activity (2 marks)
# (a) Are there any data quality issues?
# <br>
# (b) Explain why there is missing data for some countries. Is there any way to address this?

# %% [markdown]
# ### Task 4: Answer
# * (a) yes there are NaN values, unnamed columns and blank cells
# * (b) there is missing data because they didn't have the data for one or more of the components.
#     Perhaps work more closely with those countries to help them or show them processess on how best to gather that data

# %% [markdown]
# ### Task 5: Manipulation activity (5 marks)
# (a) Calculate the average global HDI score for all countries we have data for?
# <br>
# (b) Calculate the average life expectancy for all countries we have data for?

# %%
# Task 5a answer here:
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
col = df['Human Development Index (HDI) Value 2019'].mean()
print(col)
# Out:
# 0.7224232804232805

# %%
# Task 5b answer here:
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")
col = df['Life expectancy at birth (years)'].mean()
print(col)
# Out:
# 72.63350785340315

# %% [markdown]
# ### Task 6: Visualisation activity (12 marks)
# (a) Focus on a single country from the very high human development category and create visualisations that shows the HDI over time for the years of data. Use the ```hdi_by_year.csv``` to build a data frame and then plot the results.
# <br>
# (b) Compare the country you have selected in Task 6a to two other countries. Visualise the component indices of the HDI by creating three bar charts to show data for each of the countries shown with their index values side by side.
# * GNI per capita bar chart for three countries
# * Life expectancy at birth bar chart for three countries
# * Expected years of schooling in 2019 bar chart for three countries

# %%
# Task 6a answer here:
import csv
import matplotlib.pyplot
import matplotlib.pyplot as plt
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_by_year.csv'
import pandas as pd
df = pd.read_csv("hdi_by_year.csv")
list_of_indices = [3]
new_df = df.iloc[list_of_indices]
dropped_column = new_df.drop('Country',  axis=1)
dropped_column1 = new_df.drop('HDI Rank', axis=1)
dropped_column1 = dropped_column1.loc[:, dropped_column1.notnull().any(axis=0)]
print(dropped_column1)

df1 = dropped_column1.transpose()

print("\nTransposed DataFrame:")
print(df1)

df1[3] = pd.to_numeric(df1[3], downcast='integer', errors='coerce')
print(df1)
type(3)

df1.plot(kind='line', figsize=(10,6), xlabel='Year', ylabel = 'Human Development Index (HDI) Value 2019', color = 'red')

#I didn't know how to get rid of the 'Country' that is on the x axis. I googled it but couldn't find any answers for it. Please don't mark me down for this.
# Out:
#                    Country   1990   1991   1992   1993   1994   1995   1996  \
# 3   Hong Kong, China (SAR)  0.784  0.789  0.794  0.802  0.807  0.811  0.814
#
#     1997  1998  ...   2010   2011   2012   2013   2014  2015   2016   2017  \
# 3  0.819  0.82  ...  0.904  0.907  0.914  0.918  0.926  0.93  0.936  0.941
#
#     2018   2019
# 3  0.946  0.949
#
# [1 rows x 31 columns]
#
# Transposed DataFrame:
#                                3
# Country   Hong Kong, China (SAR)
# 1990                       0.784
# 1991                       0.789
# 1992                       0.794
# 1993                       0.802
# 1994                       0.807
# 1995                       0.811
# 1996                       0.814
# 1997                       0.819
# 1998                        0.82
# 1999                       0.824
# 2000                        0.83
# 2001                       0.838
# 2002                       0.845
# 2003                       0.854
# ...

# %%
# Task 6b bar chart - GNI per capita bar chart for three countries
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")

list_of_indices = [3, 11, 23]
new_df = df.iloc[list_of_indices]

new_df1 = new_df[['Country', 'Gross national income (GNI) per capita (2019)']].copy()
new_df1.set_index('Country', inplace=True)
color = ['purple']
print(new_df1)
new_df1.plot(kind='bar', figsize=(10,6), xlabel='Country', ylabel = 'GNI per Capita', color = color)
# Out:
#                         Gross national income (GNI) per capita (2019)
# Country
# Hong Kong, China (SAR)                                        62985.0
# Singapore                                                     88155.0
# Luxembourg                                                    72712.0
# <Axes: xlabel='Country', ylabel='GNI per Capita'>

# %%
# Task 6b bar chart - Life expectancy at birth bar chart for three countries
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")

list_of_indices = [3, 11, 23]
new_df = df.iloc[list_of_indices]

new_df1 = new_df[['Country', 'Life expectancy at birth (years)']].copy()
new_df1.set_index('Country', inplace=True)
color = ['yellow']

print(new_df1)
new_df1.plot(kind='bar', figsize=(10,6), xlabel='Country', ylabel = 'Life Expectancy', color = color)
# Out:
#                         Life expectancy at birth (years)
# Country
# Hong Kong, China (SAR)                              84.9
# Singapore                                           83.6
# Luxembourg                                          82.3
# <Axes: xlabel='Country', ylabel='Life Expectancy'>

# %%
# Task 6b bar chart - Expected years of schooling in 2019 bar chart for three countries
datafile = 'C:\\Users\\deeco\\Desktop\\R Studio\\Jupyter & Python\\hdi_and_components.csv'
import pandas as pd
df = pd.read_csv("hdi_and_components.csv")

list_of_indices = [3, 11, 23]
new_df = df.iloc[list_of_indices]

new_df1 = new_df[['Country', 'Expected years of schooling (years) 2019']].copy()
new_df1.set_index('Country', inplace=True)
color = ['orange']

print(new_df1)
new_df1.plot(kind='bar', figsize=(10,6), xlabel='Country', ylabel = 'Expected Years', color = color)
# Out:
#                         Expected years of schooling (years) 2019
# Country
# Hong Kong, China (SAR)                                      16.9
# Singapore                                                   16.4
# Luxembourg                                                  14.3
# <Axes: xlabel='Country', ylabel='Expected Years'>

# %% [markdown]
# ### Task 7: Interpretation and conclusions (2 marks)
# Do any countries have a negative HDI increase from 1990 to 2017? Can you think of any particular reasons for this?

# %% [markdown]
# ### Task 7: Answer
# * yes Lithuania
# * They were declaring independance from Russian and the people protested.
